# %% [markdown]
# These plots are of the allele frequencies of the first alternate allele.
#
# Strelka's normal is effectively 0, whilst the tumor is mostly under 0.2

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Adjust plot size
#options(repr.plot.width=16, repr.plot.height=6)

# For some reason, if this is in the same cell as the import command, it doesn't work.
plt.rcParams["figure.figsize"] = [18.0,8.0]

# %%
ratios = pd.read_csv('data/983899.allele_ratios.csv',sep='\t',usecols=['ALT1_RATIO'])
ratios.plot(kind='hist',title="Raw Tumor VCF",bins=100)

# %%
ratios = pd.read_csv('data/983899.filtered.allele_ratios.csv',sep='\t',usecols=['ALT1_RATIO'])
ratios.plot(kind='hist',title="Raw Tumor Filtered VCF",bins=100)

# %%
ratios = pd.read_csv('data/983899.allele_filtered.allele_ratios.csv',sep='\t',usecols=['ALT1_RATIO'])
ratios.plot(kind='hist',title="Raw Tumor Filtered VCF plus by allele frequency of 0.45",bins=100)

# %%
ratios = pd.read_csv('data/983899.strelka.normal.allele_ratios.csv',sep='\t',usecols=['ALT1_RATIO'])
ratios.plot(kind='hist',title="Strelka Normal VCF",bins=100)

# %%
ratios = pd.read_csv('data/983899.strelka.normal.filtered.allele_ratios.csv',sep='\t',usecols=['ALT1_RATIO'])
ratios.plot(kind='hist',title="Strelka Normal Filtered VCF",bins=100)

# %%
ratios = pd.read_csv('data/983899.strelka.tumor.allele_ratios.csv',sep='\t',usecols=['ALT1_RATIO'])
ratios.plot(kind='hist',title="Strelka Tumor VCF",bins=100)

# %%
ratios = pd.read_csv('data/983899.strelka.tumor.filtered.allele_ratios.csv',sep='\t',usecols=['ALT1_RATIO'])
ratios.plot(kind='hist',title="Strelka Tumor Filtered VCF",bins=100)
