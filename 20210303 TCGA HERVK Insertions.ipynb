# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '1.1.5'

# %%
import matplotlib.pyplot as plt

# %%
# Adjust plot size
#options(repr.plot.width=16, repr.plot.height=6)

# For some reason, if this is in the same cell as the import command, it doesn't work.
plt.rcParams["figure.figsize"] = [18.0,8.0]

# %%
cm=pd.read_csv("count_matrix.csv")
cm.rename(columns={"subject": "sample"},inplace=True)

# %%
cm['subject']=cm['sample'].astype(str).str[0:7]

# %%
cm.shape
# Out:
# (274, 59)

# %%
cm.head()
# Out:
#         sample  raw pair count  HERVK113 unpaired reads aligned  \
# 0  02-2483-01A       566024474                             5217
# 1  02-2483-10A       579304076                             4735
# 2  02-2485-01A       575060540                             5140
# 3  02-2485-10A       478851061                             3895
# 4  06-0125-01A      1066268796                             8464
#
#    HERVK113 unpaired human Q00 aligned  HERVK113 unpaired human Q10 aligned  \
# 0                                 5099                                 2910
# 1                                 4646                                 2687
# 2                                 5047                                 2904
# 3                                 3849                                 2229
# 4                                 8384                                 4874
#
#    HERVK113 unpaired human Q20 aligned  HERVK113 paired reads aligned  \
# 0                                 2894                           3558
# 1                                 2673                           3338
# 2                                 2892                           3782
# 3                                 2221                           2564
# 4                                 4853                           5920
#
#    HERVK113 paired human Q00 aligned  HERVK113 paired human Q10 aligned  \
# 0                               1493                               1345
# 1                               1474                               1333
# 2                               1671                               1547
# 3                               1162                               1073
# 4                               2720                               2538
#
#    HERVK113 paired human Q20 aligned  ...  SVA_E paired human Q20 aligned  \
# 0                               1328  ...                            4581
# 1                               1308  ...                            4016
# 2                               1523  ...                            4690
# 3                               1061  ...                            3959
# 4                               2514  ...                           10953
#
#    SVA_F unpaired reads aligned  SVA_F unpaired human Q00 aligned  \
# 0                         12823                             11788
# 1                         10290                              9529
# 2                         11766                             10748
# 3                          8731                              8061
# 4                         24154                             22406
#
#    SVA_F unpaired human Q10 aligned  SVA_F unpaired human Q20 aligned  \
# 0                              4762                              4719
# 1                              3830                              3791
# 2                              4482                              4433
# 3                              3293                              3252
# 4                              9480                              9421
#
#    SVA_F paired reads aligned  SVA_F paired human Q00 aligned  \
# 0                        8134                            2632
# 1                        6732                            2296
# 2                        8146                            2701
# 3                        6392                            2246
# 4                       17454                            6553
#
#    SVA_F paired human Q10 aligned  SVA_F paired human Q20 aligned  subject
# 0                            2216                            2170  02-2483
# 1                            1910                            1878  02-2483
# 2                            2262                            2217  02-2485
# 3                            1893                            1860  02-2485
# 4                            5567                            5507  06-0125
#
# [5 rows x 59 columns]

# %%
cm[['subject','sample']].head()
# Out:
#    subject       sample
# 0  02-2483  02-2483-01A
# 1  02-2483  02-2483-10A
# 2  02-2485  02-2485-01A
# 3  02-2485  02-2485-10A
# 4  06-0125  06-0125-01A

# %%
mt=pd.read_csv("metadata.cart.TCGA.GBM-LGG.WGS.bam.2020-07-17.csv",header=None,
 names=['submitter','days_to_death','gender','disease_type','center_name'])

# %%
mt.shape
# Out:
# (127, 5)

# %%
mt.head()
# Out:
#   submitter  days_to_death  gender             disease_type  \
# 0   02-2483            NaN    male  Glioblastoma Multiforme
# 1   02-2485            NaN    male  Glioblastoma Multiforme
# 2   06-0125         1448.0  female  Glioblastoma Multiforme
# 3   06-0152          375.0    male  Glioblastoma Multiforme
# 4   06-0157           97.0  female  Glioblastoma Multiforme
#
#                           center_name
# 0  Broad Institute of MIT and Harvard
# 1  Broad Institute of MIT and Harvard
# 2  Broad Institute of MIT and Harvard
# 3  Broad Institute of MIT and Harvard
# 4  Broad Institute of MIT and Harvard

# %%
merged=cm.merge(mt,left_on='subject',right_on='submitter',suffixes=["_cm","_mt"],how='outer')

# %%
merged.head()
# Out:
#         sample  raw pair count  HERVK113 unpaired reads aligned  \
# 0  02-2483-01A       566024474                             5217
# 1  02-2483-10A       579304076                             4735
# 2  02-2485-01A       575060540                             5140
# 3  02-2485-10A       478851061                             3895
# 4  06-0125-01A      1066268796                             8464
#
#    HERVK113 unpaired human Q00 aligned  HERVK113 unpaired human Q10 aligned  \
# 0                                 5099                                 2910
# 1                                 4646                                 2687
# 2                                 5047                                 2904
# 3                                 3849                                 2229
# 4                                 8384                                 4874
#
#    HERVK113 unpaired human Q20 aligned  HERVK113 paired reads aligned  \
# 0                                 2894                           3558
# 1                                 2673                           3338
# 2                                 2892                           3782
# 3                                 2221                           2564
# 4                                 4853                           5920
#
#    HERVK113 paired human Q00 aligned  HERVK113 paired human Q10 aligned  \
# 0                               1493                               1345
# 1                               1474                               1333
# 2                               1671                               1547
# 3                               1162                               1073
# 4                               2720                               2538
#
#    HERVK113 paired human Q20 aligned  ...  SVA_F paired reads aligned  \
# 0                               1328  ...                        8134
# 1                               1308  ...                        6732
# 2                               1523  ...                        8146
# 3                               1061  ...                        6392
# 4                               2514  ...                       17454
#
#    SVA_F paired human Q00 aligned  SVA_F paired human Q10 aligned  \
# 0                            2632                            2216
# 1                            2296                            1910
# 2                            2701                            2262
# 3                            2246                            1893
# 4                            6553                            5567
#
#    SVA_F paired human Q20 aligned  subject  submitter  days_to_death  gender  \
# 0                            2170  02-2483    02-2483            NaN    male
# 1                            1878  02-2483    02-2483            NaN    male
# 2                            2217  02-2485    02-2485            NaN    male
# 3                            1860  02-2485    02-2485            NaN    male
# 4                            5507  06-0125    06-0125         1448.0  female
#
#               disease_type                         center_name
# 0  Glioblastoma Multiforme  Broad Institute of MIT and Harvard
# 1  Glioblastoma Multiforme  Broad Institute of MIT and Harvard
# 2  Glioblastoma Multiforme  Broad Institute of MIT and Harvard
# 3  Glioblastoma Multiforme  Broad Institute of MIT and Harvard
# 4  Glioblastoma Multiforme  Broad Institute of MIT and Harvard
#
# [5 rows x 64 columns]

# %%
merged.shape
# Out:
# (279, 64)

# %%
df=merged[merged['center_name'] == 'Broad Institute of MIT and Harvard'].copy()

# %%
df.shape
# Out:
# (174, 64)

# %%
df['normalized HERVK113 paired human Q00 aligned']=df['HERVK113 paired human Q00 aligned']/df['raw pair count']

# %%
df['normalized HERVK113 paired human Q10 aligned']=df['HERVK113 paired human Q10 aligned']/df['raw pair count']

# %%
df['normalized HERVK113 paired human Q20 aligned']=df['HERVK113 paired human Q20 aligned']/df['raw pair count']

# %%
groups = df.groupby('disease_type')
fig, ax = plt.subplots()
for name, group in groups:
    ax.bar(group['sample'],group['raw pair count'], label=name)
ax.legend()

# %%
tumor=df[df['sample'].str.contains("-01.$")].copy()

# %%
tumor.shape
# Out:
# (73, 67)

# %%
tumor.head()
# Out:
#          sample  raw pair count  HERVK113 unpaired reads aligned  \
# 0   02-2483-01A       566024474                             5217
# 2   02-2485-01A       575060540                             5140
# 4   06-0125-01A      1066268796                             8464
# 8   06-0157-01A       551037711                             5322
# 10  06-0171-01A      1170585350                             9069
#
#     HERVK113 unpaired human Q00 aligned  HERVK113 unpaired human Q10 aligned  \
# 0                                  5099                                 2910
# 2                                  5047                                 2904
# 4                                  8384                                 4874
# 8                                  5247                                 3005
# 10                                 8940                                 5227
#
#     HERVK113 unpaired human Q20 aligned  HERVK113 paired reads aligned  \
# 0                                  2894                           3558
# 2                                  2892                           3782
# 4                                  4853                           5920
# 8                                  2996                           3280
# 10                                 5190                           6420
#
#     HERVK113 paired human Q00 aligned  HERVK113 paired human Q10 aligned  \
# 0                                1493                               1345
# 2                                1671                               1547
# 4                                2720                               2538
# 8                                1465                               1361
# 10                               2949                               2719
#
#     HERVK113 paired human Q20 aligned  ...  SVA_F paired human Q20 aligned  \
# 0                                1328  ...                            2170
# 2                                1523  ...                            2217
# 4                                2514  ...                            5507
# 8                                1338  ...                            2576
# 10                               2672  ...                            5693
#
#     subject  submitter  days_to_death  gender             disease_type  \
# 0   02-2483    02-2483            NaN    male  Glioblastoma Multiforme
# 2   02-2485    02-2485            NaN    male  Glioblastoma Multiforme
# 4   06-0125    06-0125         1448.0  female  Glioblastoma Multiforme
# 8   06-0157    06-0157           97.0  female  Glioblastoma Multiforme
# 10  06-0171    06-0171          399.0    male  Glioblastoma Multiforme
#
#                            center_name  \
# 0   Broad Institute of MIT and Harvard
# 2   Broad Institute of MIT and Harvard
# 4   Broad Institute of MIT and Harvard
# 8   Broad Institute of MIT and Harvard
# 10  Broad Institute of MIT and Harvard
#
#     normalized HERVK113 paired human Q00 aligned  \
# 0                                       0.000003
# 2                                       0.000003
# 4                                       0.000003
# 8                                       0.000003
# 10                                      0.000003
#
#     normalized HERVK113 paired human Q10 aligned  \
# 0                                       0.000002
# 2                                       0.000003
# 4                                       0.000002
# 8                                       0.000002
# 10                                      0.000002
#
#     normalized HERVK113 paired human Q20 aligned
# 0                                       0.000002
# 2                                       0.000003
# 4                                       0.000002
# 8                                       0.000002
# 10                                      0.000002
#
# [5 rows x 67 columns]

# %%
normal=df[df['sample'].str.contains("-10.$")].copy()

# %%
normal.shape
# Out:
# (74, 67)

# %%
normal.head()
# Out:
#          sample  raw pair count  HERVK113 unpaired reads aligned  \
# 1   02-2483-10A       579304076                             4735
# 3   02-2485-10A       478851061                             3895
# 6   06-0125-10A       695377506                             5184
# 9   06-0157-10A       561676819                             4434
# 12  06-0171-10A       721570484                             5428
#
#     HERVK113 unpaired human Q00 aligned  HERVK113 unpaired human Q10 aligned  \
# 1                                  4646                                 2687
# 3                                  3849                                 2229
# 6                                  5103                                 2905
# 9                                  4345                                 2471
# 12                                 5302                                 3065
#
#     HERVK113 unpaired human Q20 aligned  HERVK113 paired reads aligned  \
# 1                                  2673                           3338
# 3                                  2221                           2564
# 6                                  2892                           3778
# 9                                  2458                           3040
# 12                                 3048                           3472
#
#     HERVK113 paired human Q00 aligned  HERVK113 paired human Q10 aligned  \
# 1                                1474                               1333
# 3                                1162                               1073
# 6                                1643                               1520
# 9                                1303                               1195
# 12                               1440                               1322
#
#     HERVK113 paired human Q20 aligned  ...  SVA_F paired human Q20 aligned  \
# 1                                1308  ...                            1878
# 3                                1061  ...                            1860
# 6                                1494  ...                            2748
# 9                                1179  ...                            2022
# 12                               1306  ...                            2350
#
#     subject  submitter  days_to_death  gender             disease_type  \
# 1   02-2483    02-2483            NaN    male  Glioblastoma Multiforme
# 3   02-2485    02-2485            NaN    male  Glioblastoma Multiforme
# 6   06-0125    06-0125         1448.0  female  Glioblastoma Multiforme
# 9   06-0157    06-0157           97.0  female  Glioblastoma Multiforme
# 12  06-0171    06-0171          399.0    male  Glioblastoma Multiforme
#
#                            center_name  \
# 1   Broad Institute of MIT and Harvard
# 3   Broad Institute of MIT and Harvard
# 6   Broad Institute of MIT and Harvard
# 9   Broad Institute of MIT and Harvard
# 12  Broad Institute of MIT and Harvard
#
#     normalized HERVK113 paired human Q00 aligned  \
# 1                                       0.000003
# 3                                       0.000002
# 6                                       0.000002
# 9                                       0.000002
# 12                                      0.000002
#
#     normalized HERVK113 paired human Q10 aligned  \
# 1                                       0.000002
# 3                                       0.000002
# 6                                       0.000002
# 9                                       0.000002
# 12                                      0.000002
#
#     normalized HERVK113 paired human Q20 aligned
# 1                                       0.000002
# 3                                       0.000002
# 6                                       0.000002
# 9                                       0.000002
# 12                                      0.000002
#
# [5 rows x 67 columns]

# %% [markdown]
# # Raw counts

# %%
tumor.plot(x='sample',y='raw pair count',kind='bar')

# %%
normal.plot(x='sample',y='raw pair count',kind='bar')

# %%
normal['subject']
# Out:
# 1      02-2483
# 3      02-2485
# 6      06-0125
# 9      06-0157
# 12     06-0171
#         ...
# 265    IK-7675
# 268    TM-A7CF
# 272    TQ-A7RK
# 275    TQ-A7RV
# 278    TQ-A8XE
# Name: subject, Length: 74, dtype: object

# %%
tumor['subject']
# Out:
# 0      02-2483
# 2      02-2485
# 4      06-0125
# 8      06-0157
# 10     06-0171
#         ...
# 264    IK-7675
# 266    TM-A7CF
# 269    TQ-A7RK
# 273    TQ-A7RV
# 276    TQ-A8XE
# Name: subject, Length: 73, dtype: object

# %% [markdown]
# ## Tumor Normal comparison

# %%
#tn=normal.join(tumor,on='subject',lsuffix="_normal",rsuffix="_tumor",how='outer')
tn=normal.merge(tumor,on='subject',suffixes=["_normal","_tumor"],how='outer')

# %%
tn.head()
# Out:
#   sample_normal  raw pair count_normal  \
# 0   02-2483-10A              579304076
# 1   02-2485-10A              478851061
# 2   06-0125-10A              695377506
# 3   06-0157-10A              561676819
# 4   06-0171-10A              721570484
#
#    HERVK113 unpaired reads aligned_normal  \
# 0                                    4735
# 1                                    3895
# 2                                    5184
# 3                                    4434
# 4                                    5428
#
#    HERVK113 unpaired human Q00 aligned_normal  \
# 0                                        4646
# 1                                        3849
# 2                                        5103
# 3                                        4345
# 4                                        5302
#
#    HERVK113 unpaired human Q10 aligned_normal  \
# 0                                        2687
# 1                                        2229
# 2                                        2905
# 3                                        2471
# 4                                        3065
#
#    HERVK113 unpaired human Q20 aligned_normal  \
# 0                                        2673
# 1                                        2221
# 2                                        2892
# 3                                        2458
# 4                                        3048
#
#    HERVK113 paired reads aligned_normal  \
# 0                                  3338
# 1                                  2564
# 2                                  3778
# 3                                  3040
# 4                                  3472
#
#    HERVK113 paired human Q00 aligned_normal  \
# 0                                      1474
# 1                                      1162
# 2                                      1643
# 3                                      1303
# 4                                      1440
#
#    HERVK113 paired human Q10 aligned_normal  \
# 0                                      1333
# 1                                      1073
# 2                                      1520
# 3                                      1195
# 4                                      1322
#
#    HERVK113 paired human Q20 aligned_normal  ...  \
# 0                                      1308  ...
# 1                                      1061  ...
# 2                                      1494  ...
# 3                                      1179  ...
# 4                                      1306  ...
#
#    SVA_F paired human Q10 aligned_tumor  SVA_F paired human Q20 aligned_tumor  \
# 0                                2216.0                                2170.0
# 1                                2262.0                                2217.0
# 2                                5567.0                                5507.0
# 3                                2611.0                                2576.0
# 4                                5768.0                                5693.0
#
#    submitter_tumor  days_to_death_tumor  gender_tumor  \
# 0          02-2483                  NaN          male
# 1          02-2485                  NaN          male
# 2          06-0125               1448.0        female
# 3          06-0157                 97.0        female
# 4          06-0171                399.0          male
#
#         disease_type_tumor                   center_name_tumor  \
# 0  Glioblastoma Multiforme  Broad Institute of MIT and Harvard
# 1  Glioblastoma Multiforme  Broad Institute of MIT and Harvard
# 2  Glioblastoma Multiforme  Broad Institute of MIT and Harvard
# 3  Glioblastoma Multiforme  Broad Institute of MIT and Harvard
# 4  Glioblastoma Multiforme  Broad Institute of MIT and Harvard
#
#    normalized HERVK113 paired human Q00 aligned_tumor  \
# 0                                           0.000003
# 1                                           0.000003
# 2                                           0.000003
# 3                                           0.000003
# 4                                           0.000003
#
#    normalized HERVK113 paired human Q10 aligned_tumor  \
# 0                                           0.000002
# 1                                           0.000003
# 2                                           0.000002
# 3                                           0.000002
# 4                                           0.000002
#
#    normalized HERVK113 paired human Q20 aligned_tumor
# 0                                           0.000002
# 1                                           0.000003
# 2                                           0.000002
# 3                                           0.000002
# 4                                           0.000002
#
# [5 rows x 133 columns]

# %%
tn[['subject','sample_normal','raw pair count_normal','sample_tumor','raw pair count_tumor']].head()
# Out:
#    subject sample_normal  raw pair count_normal sample_tumor  \
# 0  02-2483   02-2483-10A              579304076  02-2483-01A
# 1  02-2485   02-2485-10A              478851061  02-2485-01A
# 2  06-0125   06-0125-10A              695377506  06-0125-01A
# 3  06-0157   06-0157-10A              561676819  06-0157-01A
# 4  06-0171   06-0171-10A              721570484  06-0171-01A
#
#    raw pair count_tumor
# 0          5.660245e+08
# 1          5.750605e+08
# 2          1.066269e+09
# 3          5.510377e+08
# 4          1.170585e+09

# %%
plt.rcParams["figure.figsize"] = [18.0,18.0]

# %%
# days_to_death	gender	disease_type	center_name
tn.plot(x='raw pair count_normal',y='raw pair count_tumor',kind='scatter')

# %%
groups = tn.groupby('gender_normal')
fig, ax = plt.subplots()
for name, group in groups:
    ax.plot(group['raw pair count_normal'],group['raw pair count_tumor'],
        marker='o', linestyle='', ms=12, label=name)
ax.legend()
# Out:
# /Users/jakewendt/Library/Python/3.6/lib/python/site-packages/matplotlib/cbook/__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x[:, None]
# /Users/jakewendt/Library/Python/3.6/lib/python/site-packages/matplotlib/axes/_base.py:276: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# /Users/jakewendt/Library/Python/3.6/lib/python/site-packages/matplotlib/axes/_base.py:278: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]

# %%
groups = tn.groupby('center_name_normal')
fig, ax = plt.subplots()
for name, group in groups:
    ax.plot(group['raw pair count_normal'],group['raw pair count_tumor'],
        marker='o', linestyle='', ms=12, label=name)
ax.legend()
# Out:
# /Users/jakewendt/Library/Python/3.6/lib/python/site-packages/matplotlib/cbook/__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x[:, None]
# /Users/jakewendt/Library/Python/3.6/lib/python/site-packages/matplotlib/axes/_base.py:276: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# /Users/jakewendt/Library/Python/3.6/lib/python/site-packages/matplotlib/axes/_base.py:278: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]

# %%
groups = tn.groupby('disease_type_normal')
fig, ax = plt.subplots()
for name, group in groups:
    ax.plot(group['raw pair count_normal'],group['raw pair count_tumor'],
        marker='o', linestyle='', ms=12, label=name)
ax.legend()
# Out:
# /Users/jakewendt/Library/Python/3.6/lib/python/site-packages/matplotlib/cbook/__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x[:, None]
# /Users/jakewendt/Library/Python/3.6/lib/python/site-packages/matplotlib/axes/_base.py:276: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# /Users/jakewendt/Library/Python/3.6/lib/python/site-packages/matplotlib/axes/_base.py:278: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]

# %%
plt.rcParams["figure.figsize"] = [18.0,8.0]

# %%
tn['raw count ratio']=tn['raw pair count_tumor']/tn['raw pair count_normal']

# %%
tn.plot(x='subject',y='raw count ratio',kind='bar')

# %%
df[df['subject']=='CS-5390']
# Out:
#          sample  raw pair count  HERVK113 unpaired reads aligned  \
# 84  CS-5390-10A       529225224                             4273
#
#     HERVK113 unpaired human Q00 aligned  HERVK113 unpaired human Q10 aligned  \
# 84                                 4213                                 2422
#
#     HERVK113 unpaired human Q20 aligned  HERVK113 paired reads aligned  \
# 84                                 2419                           2814
#
#     HERVK113 paired human Q00 aligned  HERVK113 paired human Q10 aligned  \
# 84                               1269                               1180
#
#     HERVK113 paired human Q20 aligned  ...  SVA_F paired human Q20 aligned  \
# 84                               1161  ...                            1290
#
#     subject  submitter  days_to_death  gender              disease_type  \
# 84  CS-5390    CS-5390            NaN  female  Brain Lower Grade Glioma
#
#                            center_name  \
# 84  Broad Institute of MIT and Harvard
#
#     normalized HERVK113 paired human Q00 aligned  \
# 84                                      0.000002
#
#     normalized HERVK113 paired human Q10 aligned  \
# 84                                      0.000002
#
#     normalized HERVK113 paired human Q20 aligned
# 84                                      0.000002
#
# [1 rows x 67 columns]

# %% [markdown]
# # Below are plots of total HERV insertion counts

# %%
plt.rcParams["figure.figsize"] = [18.0,8.0]

# %% [markdown]
# ## Tumor counts

# %%
tumor.plot(x='sample',y='HERVK113 unpaired human Q00 aligned',kind='bar')

# %%
tumor.plot(x='sample',y='normalized HERVK113 paired human Q00 aligned',kind='bar')

# %%
tumor.plot(x='sample',y='normalized HERVK113 paired human Q20 aligned',kind='bar')

# %% [markdown]
# ## Normal HERV counts

# %%
normal.plot(x='sample',y='normalized HERVK113 paired human Q00 aligned',kind='bar')

# %%
normal.plot(x='sample',y='normalized HERVK113 paired human Q20 aligned',kind='bar')

# %%
normal.head()
# Out:
#          sample  raw pair count  HERVK113 unpaired reads aligned  \
# 1   02-2483-10A       579304076                             4735
# 3   02-2485-10A       478851061                             3895
# 6   06-0125-10A       695377506                             5184
# 9   06-0157-10A       561676819                             4434
# 12  06-0171-10A       721570484                             5428
#
#     HERVK113 unpaired human Q00 aligned  HERVK113 unpaired human Q10 aligned  \
# 1                                  4646                                 2687
# 3                                  3849                                 2229
# 6                                  5103                                 2905
# 9                                  4345                                 2471
# 12                                 5302                                 3065
#
#     HERVK113 unpaired human Q20 aligned  HERVK113 paired reads aligned  \
# 1                                  2673                           3338
# 3                                  2221                           2564
# 6                                  2892                           3778
# 9                                  2458                           3040
# 12                                 3048                           3472
#
#     HERVK113 paired human Q00 aligned  HERVK113 paired human Q10 aligned  \
# 1                                1474                               1333
# 3                                1162                               1073
# 6                                1643                               1520
# 9                                1303                               1195
# 12                               1440                               1322
#
#     HERVK113 paired human Q20 aligned  ...  SVA_F paired human Q20 aligned  \
# 1                                1308  ...                            1878
# 3                                1061  ...                            1860
# 6                                1494  ...                            2748
# 9                                1179  ...                            2022
# 12                               1306  ...                            2350
#
#     subject  submitter  days_to_death  gender             disease_type  \
# 1   02-2483    02-2483            NaN    male  Glioblastoma Multiforme
# 3   02-2485    02-2485            NaN    male  Glioblastoma Multiforme
# 6   06-0125    06-0125         1448.0  female  Glioblastoma Multiforme
# 9   06-0157    06-0157           97.0  female  Glioblastoma Multiforme
# 12  06-0171    06-0171          399.0    male  Glioblastoma Multiforme
#
#                            center_name  \
# 1   Broad Institute of MIT and Harvard
# 3   Broad Institute of MIT and Harvard
# 6   Broad Institute of MIT and Harvard
# 9   Broad Institute of MIT and Harvard
# 12  Broad Institute of MIT and Harvard
#
#     normalized HERVK113 paired human Q00 aligned  \
# 1                                       0.000003
# 3                                       0.000002
# 6                                       0.000002
# 9                                       0.000002
# 12                                      0.000002
#
#     normalized HERVK113 paired human Q10 aligned  \
# 1                                       0.000002
# 3                                       0.000002
# 6                                       0.000002
# 9                                       0.000002
# 12                                      0.000002
#
#     normalized HERVK113 paired human Q20 aligned
# 1                                       0.000002
# 3                                       0.000002
# 6                                       0.000002
# 9                                       0.000002
# 12                                      0.000002
#
# [5 rows x 67 columns]

# %%
groups = normal.groupby('center_name')
fig, ax = plt.subplots()
plt.xticks(rotation=90)
for name, group in groups:
    ax.bar(group['sample'],group['normalized HERVK113 paired human Q20 aligned'], label=name)
ax.legend()

# %%
merged[merged['subject']=='CS-4941']
# Out:
#          sample  raw pair count  HERVK113 unpaired reads aligned  \
# 80  CS-4941-01A       258889928                              246
# 81  CS-4941-10A       282839817                              282
#
#     HERVK113 unpaired human Q00 aligned  HERVK113 unpaired human Q10 aligned  \
# 80                                  246                                   68
# 81                                  280                                   63
#
#     HERVK113 unpaired human Q20 aligned  HERVK113 paired reads aligned  \
# 80                                   68                            212
# 81                                   63                            296
#
#     HERVK113 paired human Q00 aligned  HERVK113 paired human Q10 aligned  \
# 80                                 98                                 93
# 81                                125                                114
#
#     HERVK113 paired human Q20 aligned  ...  SVA_F paired reads aligned  \
# 80                                 93  ...                         350
# 81                                114  ...                         466
#
#     SVA_F paired human Q00 aligned  SVA_F paired human Q10 aligned  \
# 80                             140                             114
# 81                             179                             141
#
#     SVA_F paired human Q20 aligned  subject  submitter  days_to_death  gender  \
# 80                             114  CS-4941    CS-4941          234.0    male
# 81                             138  CS-4941    CS-4941          234.0    male
#
#                 disease_type             center_name
# 80  Brain Lower Grade Glioma  Harvard Medical School
# 81  Brain Lower Grade Glioma  Harvard Medical School
#
# [2 rows x 64 columns]

# %%
merged[merged['subject']=='06-0125']
# Out:
#         sample  raw pair count  HERVK113 unpaired reads aligned  \
# 4  06-0125-01A      1066268796                             8464
# 5  06-0125-02A      1083260581                             8642
# 6  06-0125-10A       695377506                             5184
#
#    HERVK113 unpaired human Q00 aligned  HERVK113 unpaired human Q10 aligned  \
# 4                                 8384                                 4874
# 5                                 8580                                 4943
# 6                                 5103                                 2905
#
#    HERVK113 unpaired human Q20 aligned  HERVK113 paired reads aligned  \
# 4                                 4853                           5920
# 5                                 4920                           6296
# 6                                 2892                           3778
#
#    HERVK113 paired human Q00 aligned  HERVK113 paired human Q10 aligned  \
# 4                               2720                               2538
# 5                               2888                               2702
# 6                               1643                               1520
#
#    HERVK113 paired human Q20 aligned  ...  SVA_F paired reads aligned  \
# 4                               2514  ...                       17454
# 5                               2662  ...                       15702
# 6                               1494  ...                        9524
#
#    SVA_F paired human Q00 aligned  SVA_F paired human Q10 aligned  \
# 4                            6553                            5567
# 5                            5903                            4931
# 6                            3309                            2785
#
#    SVA_F paired human Q20 aligned  subject  submitter  days_to_death  gender  \
# 4                            5507  06-0125    06-0125         1448.0  female
# 5                            4864  06-0125    06-0125         1448.0  female
# 6                            2748  06-0125    06-0125         1448.0  female
#
#               disease_type                         center_name
# 4  Glioblastoma Multiforme  Broad Institute of MIT and Harvard
# 5  Glioblastoma Multiforme  Broad Institute of MIT and Harvard
# 6  Glioblastoma Multiforme  Broad Institute of MIT and Harvard
#
# [3 rows x 64 columns]

# %%
normal.plot(x='sample',y=['normalized HERVK113 paired human Q00 aligned',
                          'normalized HERVK113 paired human Q10 aligned',
                          'normalized HERVK113 paired human Q20 aligned'],
            kind='bar')

# %%
tumor.plot(x='sample',y=['normalized HERVK113 paired human Q00 aligned',
                          'normalized HERVK113 paired human Q10 aligned',
                          'normalized HERVK113 paired human Q20 aligned'],
            kind='bar')

# %%
plt.rcParams["figure.figsize"] = [18.0,18.0]

# %%
ax=tn.plot(marker='o',linestyle='',x='subject',y='normalized HERVK113 paired human Q00 aligned_normal')
tn.plot(marker='o',linestyle='',x='subject',y='normalized HERVK113 paired human Q00 aligned_tumor',ax=ax)
tn.plot(marker='o',linestyle='',x='subject',y='normalized HERVK113 paired human Q20 aligned_normal',ax=ax)
tn.plot(marker='o',linestyle='',x='subject',y='normalized HERVK113 paired human Q20 aligned_tumor',ax=ax)
plt.xticks(rotation=90)
# Out:
# (array([-10.,   0.,  10.,  20.,  30.,  40.,  50.,  60.,  70.,  80.]),
#  <a list of 10 Text xticklabel objects>)
