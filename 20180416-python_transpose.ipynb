# %% [markdown]
# Read and rotate (transpose) a csv table in python

# %%
import pandas

# %%
df = pandas.read_csv('data/all.summary_table.raw.csv',index_col=0)

# %%
df.head()
# Out:
#                        chrM:35  chrM:41  chrM:64  chrM:103  chrM:114  \
# -
# HG00403_lcl_SRR819866        0        0        0         0         0
# HG00404_lcl_SRR819918        0        0        0         0         0
# HG00405_lcl_SRR826477        0        0        0         0         0
# HG00406_lcl_SRR826680        0        0        0         0         0
# HG00407_lcl_SRR822932        0        0        0         0         0
#
#                        chrM:143  chrM:150  chrM:151  chrM:182  chrM:185  \
# -
# HG00403_lcl_SRR819866         0         0         0         0         0
# HG00404_lcl_SRR819918         0         0         0         0         0
# HG00405_lcl_SRR826477         0         0         0         0         0
# HG00406_lcl_SRR826680         0         0         0         0         0
# HG00407_lcl_SRR822932         0         0         0         0         0
#
#                           ...      chrM:16360  chrM:16366  chrM:16380  \
# -                         ...
# ...

# %%
df = df.T

# %%
df.head()
# Out:
# -         HG00403_lcl_SRR819866  HG00404_lcl_SRR819918  HG00405_lcl_SRR826477  \
# chrM:35                       0                      0                      0
# chrM:41                       0                      0                      0
# chrM:64                       0                      0                      0
# chrM:103                      0                      0                      0
# chrM:114                      0                      0                      0
#
# -         HG00406_lcl_SRR826680  HG00407_lcl_SRR822932  HG00408_lcl_SRR826482  \
# chrM:35                       0                      0                      0
# chrM:41                       0                      0                      0
# chrM:64                       0                      0                      0
# chrM:103                      0                      0                      0
# chrM:114                      0                      0                      0
#
# ...

# %%
#df.to_csv('out.csv')
