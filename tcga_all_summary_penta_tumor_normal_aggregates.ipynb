# %%
import pandas
pandas.__version__
# Out:
# '0.22.0'

# %%
df = pandas.read_csv('data/TCGA_all.summary_table.pent.with_sums.tumor_normal_aggregates.gz',index_col=0)

# %%
df.head()
# Out:
#             tumor_minimum  normal_minimum  tumor_maximum  normal_maximum  \
# transition
# AAAAA-C                37              29            147             128
# AAAAA-G                55              39            168             157
# AAAAA-T                24              20            104              99
# AAAAC-C                15              16             51              48
# AAAAC-G                18              22             54              60
#
#             tumor_median  normal_median  tumor_mean  normal_mean
# transition
# AAAAA-C            106.0          100.0    108.8630      98.8824
# AAAAA-G            122.0          115.5    126.4710     117.4510
# AAAAA-T             71.5           67.5     72.9804      67.8039
# AAAAC-C             40.0           37.0     39.2941      37.4902
# AAAAC-G             40.0           40.5     40.2353      40.5882

# %%
df.describe()
# Out:
#        tumor_minimum  normal_minimum  tumor_maximum  normal_maximum  \
# count    3072.000000     3072.000000    3072.000000     3072.000000
# mean       12.882487       11.659505      54.482422       50.451497
# std        20.117909       17.235283      92.140014       78.645702
# min         0.000000        0.000000       0.000000        1.000000
# 25%         3.000000        2.000000      17.000000       17.000000
# 50%         6.000000        6.000000      29.000000       28.000000
# 75%        17.000000       15.000000      66.250000       63.000000
# max       262.000000      215.000000    1810.000000     1559.000000
#
#        tumor_median  normal_median   tumor_mean  normal_mean
# count   3072.000000    3072.000000  3072.000000  3072.000000
# mean      36.158691      35.272624    36.767764    35.268493
# std       45.715082      44.648989    47.620569    44.721894
# min        0.000000       0.000000     0.000000     0.019608
# 25%       10.000000      10.000000    10.701000    10.289200
# 50%       19.000000      18.000000    19.058800    18.352900
# 75%       47.500000      46.000000    47.833325    45.926500
# max      445.000000     451.000000   503.333000   443.471000

# %%
import matplotlib.pyplot as plt

# %%
print(plt.rcParams["figure.figsize"])
plt.rcParams["figure.figsize"] = [16.0,8.0]
print(plt.rcParams["figure.figsize"])
# Out:
# [6.0, 4.0]
# [16.0, 8.0]

# %%
df.plot()

# %%
len(df.query( 'tumor_maximum >= 200' ))
# Out:
# 92

# %%
df.query( 'tumor_maximum >= 200' ).plot()

# %%
df.query( 'tumor_maximum >= 200' ).plot.bar()

# %%
len(df.query( 'tumor_median >= 100' ))
# Out:
# 241

# %%
df.query( 'tumor_median >= 100' ).plot.bar()

# %%
#df.query( 'transition ~ /..C..-T/' )
#df( df['transition'] ~= /..C..-T/)

#>>> df.filter(like='bbi', axis=0)
#>>> df.filter(regex='e$', axis=1)
df.filter(regex='..C..-T',axis=0)
# Out:
#             tumor_minimum  normal_minimum  tumor_maximum  normal_maximum  \
# transition
# AACAA-T                42              36            133             128
# AACAC-T                24              32             99              85
# AACAG-T                45              38            151             145
# AACAT-T                43              47            145             133
# AACCA-T                26              20             74              85
# AACCC-T                17              13             73              73
# AACCG-T                 0               3             13              12
# AACCT-T                23              25             92              87
# AACGA-T                35              34            151             156
# AACGC-T                32              35            132             133
# AACGG-T                54              53            208             188
# AACGT-T                63              62            179             175
# AACTA-T                23              24             81              81
# AACTC-T                19              18             85              78
# AACTG-T                61              53            158             162
# AACTT-T                35              34            115             123
# ACCAA-T                12              11             68              56
# ACCAC-T                13              12             59              56
# ACCAG-T                14               9             62              58
# ACCAT-T                21              12             79              70
# ACCCA-T                25              23             93              99
# ACCCC-T                18              17             85              78
# ACCCG-T                 0               0             12              14
# TGCGC-T            247.0          236.5   249.33300    233.23500
# TGCGG-T            150.5          146.0   145.33300    140.92200
# TGCGT-T            321.0          316.5   333.27500    312.19600
# TGCTA-T             50.0           48.0    50.52940     48.50980
# TGCTC-T             58.5           60.0    58.92160     58.56860
# TGCTG-T             81.0           79.0    79.86270     78.27450
# TGCTT-T             94.5           93.0    95.31370     92.29410
# TTCAA-T             68.0           67.5    68.23530     66.13730
# TTCAC-T             57.5           55.5    56.52940     54.70590
# TTCAG-T             61.5           61.5    63.27450     61.21570
# TTCAT-T             81.0           79.0    82.74510     80.68630
# TTCCA-T             58.0           55.0    58.05880     56.39220
# TTCCC-T             83.5           85.0    86.70590     83.19610
# TTCCG-T              4.0            3.5     3.94118      3.82353
# TTCCT-T            132.5          131.0   133.37300    129.05900
# TTCGA-T             80.0           81.0    82.23530     79.64710
# TTCGC-T             78.0           74.5    78.00000     75.11760
# TTCGG-T             89.5           87.0    88.31370     85.58820
# TTCGT-T             79.0           79.0    80.84310     77.84310
# TTCTA-T             62.0           61.0    62.45100     60.29410
# TTCTC-T            107.0          105.0   109.86300    103.90200
# TTCTG-T             90.5           86.5    93.68630     86.94120
# TTCTT-T            395.5          337.0   503.33300    387.49000
#
# [256 rows x 8 columns]

# %%
df.filter(regex='..C..-T',axis=0).plot.bar()

# %%
df.filter(regex='.TC..-T',axis=0).plot.bar()

# %%
df.filter(regex='.TC..-T',axis=0).plot.bar()
plt.ylim(0,300)
plt.show()

# %%
df.filter(regex='.TCA.-T',axis=0).plot.bar()

# %%
df[['tumor_median','normal_median']].filter(regex='.TCA.-T',axis=0).plot.bar()

# %%
df[['tumor_median','normal_median']].filter(regex='.TC..-T',axis=0).plot.bar()

# %%
df.filter(regex='.TCA.-T',axis=0)
# Out:
#             tumor_minimum  normal_minimum  tumor_maximum  normal_maximum  \
# transition
# ATCAA-T                12              13             42              40
# ATCAC-T                11              13             46              49
# ATCAG-T                18              14             64              68
# ATCAT-T                23              25             65              64
# CTCAA-T                18              15             66              66
# CTCAC-T                17              12             82              69
# CTCAG-T                18              18             82              73
# CTCAT-T                21              26             80              80
# GTCAA-T                 8               8             27              27
# GTCAC-T                 9               7             39              39
# GTCAG-T                 8               9             42              39
# GTCAT-T                11              11             42              42
# TTCAA-T                22              26             87              86
# TTCAC-T                24              21             71              72
# TTCAG-T                21              24             82              82
# TTCAT-T                42              41            107             110
#
#             tumor_median  normal_median  tumor_mean  normal_mean
# transition
# ATCAA-T             29.0           28.0     29.2353      28.1176
# ATCAC-T             34.0           32.0     33.6275      32.5098
# ATCAG-T             46.0           45.0     47.1373      45.2941
# ATCAT-T             48.5           49.0     50.4314      48.7255
# CTCAA-T             51.0           50.0     50.8039      49.0784
# CTCAC-T             57.5           54.0     58.0980      53.8039
# CTCAG-T             58.5           59.0     59.4118      58.7451
# CTCAT-T             62.5           63.5     63.8431      62.9020
# GTCAA-T             19.0           19.0     19.0588      18.8235
# GTCAC-T             27.5           26.5     27.3333      26.7843
# GTCAG-T             27.0           26.5     27.4902      26.9412
# GTCAT-T             25.0           25.5     25.9608      26.9412
# TTCAA-T             68.0           67.5     68.2353      66.1373
# TTCAC-T             57.5           55.5     56.5294      54.7059
# TTCAG-T             61.5           61.5     63.2745      61.2157
# TTCAT-T             81.0           79.0     82.7451      80.6863
